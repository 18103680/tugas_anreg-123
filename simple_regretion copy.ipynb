# %%
import pandas as pd
import math

# %%
df1 = pd.read_csv('Salary_Data.csv')
df1
# Out:
#        x         y
# 0    1.1   39343.0
# 1    1.3   46205.0
# 2    1.5   37731.0
# 3    2.0   43525.0
# 4    2.2   39891.0
# 5    2.9   56642.0
# 6    3.0   60150.0
# 7    3.2   54445.0
# 8    3.2   64445.0
# 9    3.7   57189.0
# 10   3.9   63218.0
# 11   4.0   55794.0
# 12   4.0   56957.0
# 13   4.1   57081.0
# 14   4.5   61111.0
# 15   4.9   67938.0
# 16   5.1   66029.0
# 17   5.3   83088.0
# 18   5.9   81363.0
# 19   6.0   93940.0
# 20   6.8   91738.0
# 21   7.1   98273.0
# 22   7.9  101302.0
# 23   8.2  113812.0
# 24   8.7  109431.0
# 25   9.0  105582.0
# 26   9.5  116969.0
# 27   9.6  112635.0
# 28  10.3  122391.0
# 29  10.5  121872.0

# %%
print(df1['x'].describe())
# Out:
# count    30.000000
# mean      5.313333
# std       2.837888
# min       1.100000
# 25%       3.200000
# 50%       4.700000
# 75%       7.700000
# max      10.500000
# Name: x, dtype: float64

# %%
df1['xy'] = df1['x'] * df1['y']
df1['x^2'] = df1['x'] * df1['x']
df1['y^2'] = df1['y'] * df1['y']
df1
# Out:
#        x         y         xy     x^2           y^2
# 0    1.1   39343.0    43277.3    1.21  1.547872e+09
# 1    1.3   46205.0    60066.5    1.69  2.134902e+09
# 2    1.5   37731.0    56596.5    2.25  1.423628e+09
# 3    2.0   43525.0    87050.0    4.00  1.894426e+09
# 4    2.2   39891.0    87760.2    4.84  1.591292e+09
# 5    2.9   56642.0   164261.8    8.41  3.208316e+09
# 6    3.0   60150.0   180450.0    9.00  3.618022e+09
# 7    3.2   54445.0   174224.0   10.24  2.964258e+09
# 8    3.2   64445.0   206224.0   10.24  4.153158e+09
# 9    3.7   57189.0   211599.3   13.69  3.270582e+09
# 10   3.9   63218.0   246550.2   15.21  3.996516e+09
# 11   4.0   55794.0   223176.0   16.00  3.112970e+09
# 12   4.0   56957.0   227828.0   16.00  3.244100e+09
# 13   4.1   57081.0   234032.1   16.81  3.258241e+09
# 14   4.5   61111.0   274999.5   20.25  3.734554e+09
# 15   4.9   67938.0   332896.2   24.01  4.615572e+09
# 16   5.1   66029.0   336747.9   26.01  4.359829e+09
# 17   5.3   83088.0   440366.4   28.09  6.903616e+09
# 18   5.9   81363.0   480041.7   34.81  6.619938e+09
# 19   6.0   93940.0   563640.0   36.00  8.824724e+09
# 20   6.8   91738.0   623818.4   46.24  8.415861e+09
# 21   7.1   98273.0   697738.3   50.41  9.657583e+09
# 22   7.9  101302.0   800285.8   62.41  1.026210e+10
# 23   8.2  113812.0   933258.4   67.24  1.295317e+10
# 24   8.7  109431.0   952049.7   75.69  1.197514e+10
# 25   9.0  105582.0   950238.0   81.00  1.114756e+10
# 26   9.5  116969.0  1111205.5   90.25  1.368175e+10
# 27   9.6  112635.0  1081296.0   92.16  1.268664e+10
# 28  10.3  122391.0  1260627.3  106.09  1.497956e+10
# 29  10.5  121872.0  1279656.0  110.25  1.485278e+10

# %%
# menegtahui jumlah nya 
a= df1['x'].sum()
b= df1['y'].sum()
c =df1['xy'].sum()
d = df1['x^2'].sum()
e = df1['y^2'].sum()
f = df1['y'].mean()
g = df1['x'].mean()


print("Jumlah kolom 'x':", a)
print("Jumlah kolom 'y':", b)
print("Jumlah kolom 'xy':", c)
print("Jumlah kolom 'x^2':", d)
print("Jumlah kolom 'y^2':", e)
print('rata-rata y ', f)
print('rata-rata x ', g)
# Out:
# Jumlah kolom 'x': 159.4
# Jumlah kolom 'y': 2280090.0
# Jumlah kolom 'xy': 14321961.0
# Jumlah kolom 'x^2': 1080.5
# Jumlah kolom 'y^2': 195088658122.0
# rata-rata y  76003.0
# rata-rata x  5.3133333333333335

# %%
beta_1 = (c -((a*b)/30))/(d - (a**2/30))
beta_1
# Out:
# np.float64(9449.962321455081)

# %%
beta_0 = f - beta_1*g
beta_0
# Out:
# np.float64(25792.200198668666)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd  # Pastikan Anda mengimpor pandas jika menggunakan DataFrame

# Misalkan df1, beta_0, dan beta_1 sudah didefinisikan
# df1 = pd.read_csv('data.csv')  # Contoh cara membaca data
# beta_0 = 1000  # Contoh nilai beta_0
# beta_1 = 3000  # Contoh nilai beta_1

# Buat array x dari DataFrame
x = df1['x'] 

# Hitung nilai y
y = beta_0 + beta_1 * x


# Plot
plt.figure(figsize=(12, 6))
plt.plot(x, y, label=f'y = {beta_0} + {beta_1} * x', color='blue')
plt.scatter(df1['x'], df1['y'], color='red', label='Data CSV')
plt.title('Plot dari y = beta_0 + beta_1 * x')
plt.xlabel('x')
plt.ylabel('y')

# Menetapkan limit sumbu
plt.xlim(0, 11)  # Sesuaikan sesuai kebutuhan
plt.ylim(min(y), max(y))  # Sesuaikan dengan rentang nilai y yang dihitung

# Garis horizontal dan vertikal di sumbu
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')

# Mengatur ticks
plt.xticks(np.arange(0, 11, 0.5)) 
plt.yticks(np.arange(25000, max(y) + 20000, 20000))  # Menyesuaikan rentang y

plt.grid()
plt.legend()
plt.show()

# %%
df1['prediksi-taksiran'] = y = beta_0 + beta_1 * x
df1['eror'] = (df1['prediksi-taksiran'] - df1['y'])**2
df1
# Out:
#        x         y         xy     x^2           y^2  prediksi-taksiran  \
# 0    1.1   39343.0    43277.3    1.21  1.547872e+09       36187.158752
# 1    1.3   46205.0    60066.5    1.69  2.134902e+09       38077.151217
# 2    1.5   37731.0    56596.5    2.25  1.423628e+09       39967.143681
# 3    2.0   43525.0    87050.0    4.00  1.894426e+09       44692.124842
# 4    2.2   39891.0    87760.2    4.84  1.591292e+09       46582.117306
# 5    2.9   56642.0   164261.8    8.41  3.208316e+09       53197.090931
# 6    3.0   60150.0   180450.0    9.00  3.618022e+09       54142.087163
# 7    3.2   54445.0   174224.0   10.24  2.964258e+09       56032.079627
# 8    3.2   64445.0   206224.0   10.24  4.153158e+09       56032.079627
# 9    3.7   57189.0   211599.3   13.69  3.270582e+09       60757.060788
# 10   3.9   63218.0   246550.2   15.21  3.996516e+09       62647.053252
# 11   4.0   55794.0   223176.0   16.00  3.112970e+09       63592.049484
# 12   4.0   56957.0   227828.0   16.00  3.244100e+09       63592.049484
# 13   4.1   57081.0   234032.1   16.81  3.258241e+09       64537.045717
# 14   4.5   61111.0   274999.5   20.25  3.734554e+09       68317.030645
# 15   4.9   67938.0   332896.2   24.01  4.615572e+09       72097.015574
# 16   5.1   66029.0   336747.9   26.01  4.359829e+09       73987.008038
# 17   5.3   83088.0   440366.4   28.09  6.903616e+09       75877.000502
# 18   5.9   81363.0   480041.7   34.81  6.619938e+09       81546.977895
# 19   6.0   93940.0   563640.0   36.00  8.824724e+09       82491.974127
# 20   6.8   91738.0   623818.4   46.24  8.415861e+09       90051.943985
# 21   7.1   98273.0   697738.3   50.41  9.657583e+09       92886.932681
# 22   7.9  101302.0   800285.8   62.41  1.026210e+10      100446.902538
# 23   8.2  113812.0   933258.4   67.24  1.295317e+10      103281.891235
# 24   8.7  109431.0   952049.7   75.69  1.197514e+10      108006.872395
# 25   9.0  105582.0   950238.0   81.00  1.114756e+10      110841.861092
# 26   9.5  116969.0  1111205.5   90.25  1.368175e+10      115566.842252
# 27   9.6  112635.0  1081296.0   92.16  1.268664e+10      116511.838485
# 28  10.3  122391.0  1260627.3  106.09  1.497956e+10      123126.812110
# 29  10.5  121872.0  1279656.0  110.25  1.485278e+10      125016.804574
#
#             eror
# 0   9.959334e+06
# 1   6.606193e+07
# 2   5.000339e+06
# 3   1.362180e+06
# 4   4.477105e+07
# 5   1.186740e+07
# 6   3.609502e+07
# 7   2.518822e+06
# 8   7.077723e+07
# 9   1.273106e+07
# 10  3.259802e+05
# 11  6.080958e+07
# 12  4.402388e+07
# 13  5.559262e+07
# 14  5.192688e+07
# 15  1.729741e+07
# 16  6.332989e+07
# 17  5.199851e+07
# 18  3.384787e+04
# 19  1.310573e+08
# 20  2.842785e+06
# 21  2.900972e+07
# 22  7.311917e+05
# 23  1.108832e+08
# 24  2.028139e+06
# 25  2.766614e+07
# 26  1.966046e+06
# 27  1.502988e+07
# 28  5.414195e+05
# 29  9.889796e+06

# %%
variansi_residual = df1['eror'].sum()/(df1.shape[0]-2)
variansi_residual
# Out:
# np.float64(33504591.13101531)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
plt.subplot(1, 2, 1)
plt.hist(df1['eror'], bins=10, color='blue', alpha=0.7)
plt.title('Histogram Residual')
plt.xlabel('Residual (ϵ)')
plt.ylabel('Frekuensi')
plt.grid()

# Plot Q-Q Plot
plt.subplot(1, 2, 2)
stats.probplot(df1['eror'], dist="norm", plot=plt)
plt.title('Q-Q Plot Residual')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd  # Pastikan Anda mengimpor pandas jika menggunakan DataFrame

# Misalkan df1, beta_0, dan beta_1 sudah didefinisikan
# df1 = pd.read_csv('data.csv')  # Contoh cara membaca data
# beta_0 = 1000  # Contoh nilai beta_0
# beta_1 = 3000  # Contoh nilai beta_1

# Buat array x dari DataFrame
x = df1['x'] 

# Hitung nilai y untuk x dari DataFrame
y = beta_0 + beta_1 * x

# Buat array x baru
x1 = np.array([11, 12, 13])  # Menggunakan np.array untuk konsistensi
# Hitung nilai y untuk x1
y1 = beta_0 + beta_1 * x1

# Plot
plt.figure(figsize=(12, 6))

# Plot garis regresi dari DataFrame
plt.plot(x, y, label=f'y = {beta_0} + {beta_1} * x', color='blue')

# Plot garis untuk x1
plt.scatter(x1, y1, label=f'y = {beta_0} + {beta_1} * x1', color='red')
# Plot data dari CSV
plt.scatter(df1['x'], df1['y'], color='green', label='Data CSV')  # Ubah warna agar tidak sama dengan garis
plt.title('Plot dari y = beta_0 + beta_1 * x')
plt.xlabel('x')
plt.ylabel('y')

# Menetapkan limit sumbu
plt.xlim(0, 15)  # Sesuaikan sesuai kebutuhan; menambah sedikit lebih banyak untuk x1
plt.ylim(min(y), max(y) + 10000)  # Mengatur rentang y dengan sedikit padding

# Garis horizontal dan vertikal di sumbu
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')

# Mengatur ticks
plt.xticks(np.arange(0, 16, 1))  # Menyesuaikan rentang x
plt.yticks(np.arange(25000, max(y) + 20000, 20000))  # Menyesuaikan rentang y

plt.grid()
plt.legend()
plt.show()

# %%
y.head(20)
# Out:
# 0     36187.158752
# 1     38077.151217
# 2     39967.143681
# 3     44692.124842
# 4     46582.117306
# 5     53197.090931
# 6     54142.087163
# 7     56032.079627
# 8     56032.079627
# 9     60757.060788
# 10    62647.053252
# 11    63592.049484
# 12    63592.049484
# 13    64537.045717
# 14    68317.030645
# 15    72097.015574
# 16    73987.008038
# 17    75877.000502
# 18    81546.977895
# 19    82491.974127
# Name: x, dtype: float64

# %%
y.tail(10)
# Out:
# 20     90051.943985
# 21     92886.932681
# 22    100446.902538
# 23    103281.891235
# 24    108006.872395
# 25    110841.861092
# 26    115566.842252
# 27    116511.838485
# 28    123126.812110
# 29    125016.804574
# Name: x, dtype: float64

# %%
# menghitung R kuadrat
k =  ((y-f)**2)
l = ((df1['y']- f)**2)
JKR = k.sum()
JKT = l.sum()
RKR = JKT/1
JKS = JKT - JKR
dk_galat = df1.shape[0] - 2
dk_total = df1.shape[0] - 1
RKS = JKS/dk_galat
f_statistik = RKR/RKS

R_kuadrat = JKR/JKT
print("jumlah r kuadrat yaitu ",R_kuadrat)
print("nilai Jkr yaitu ",JKR)
print("nilai JKT yaitu  ",JKT)
print("nilai JKS yaitu ",JKS)
print("jumlah nilai RKR ",RKR)
print("dgree of freedom pada galat ",dk_galat)
print("print degre of freedom total ",dk_total)
print("jumlah nilai RKS ", RKS)
print("F_statisiknya yaitu ",f_statistik)
# Out:
# jumlah r kuadrat yaitu  0.9569566641435093
# nilai Jkr yaitu  20856849300.33159
# nilai JKT yaitu   21794977852.0
# nilai JKS yaitu  938128551.6684113
# jumlah nilai RKR  21794977852.0
# dgree of freedom pada galat  28
# print degre of freedom total  29
# jumlah nilai RKS  33504591.131014686
# F_statisiknya yaitu  650.5072026330363

# %%
# Menghitung p-valuenya 
from scipy import stats
x = df1['x']
y = df1['y']
n = len(x)

# Langkah 1: Hitung rata-rata x dan y
x_mean = np.mean(x)
y_mean = np.mean(y)

# Langkah 2: Hitung koefisien beta1
beta1_numerator = n * np.sum(x * y) - np.sum(x) * np.sum(y)
beta1_denominator = n * np.sum(x**2) - (np.sum(x))**2
beta1 = beta1_numerator / beta1_denominator

# Langkah 3: Hitung koefisien beta0
beta0 = y_mean - beta1 * x_mean

# Langkah 4: Hitung nilai prediksi (y_hat) dan residual
y_hat = beta0 + beta1 * x
residuals = y - y_hat

# Langkah 5: Hitung varians dari residual (s^2)
s_squared = np.sum(residuals**2) / (n - 2)

# Langkah 6: Hitung standard error dari beta1
se_beta1 = np.sqrt(s_squared / np.sum((x - x_mean)**2))

# Langkah 7: Hitung statistik t
t_statistic = beta1 / se_beta1

# Langkah 8: Hitung p-value
df = n - 2  # Derajat kebebasan
p_value = 2 * (1 - stats.t.cdf(np.abs(t_statistic), df))

# Menampilkan hasil
print(f"Koefisien beta0: {beta0}")
print(f"Koefisien beta1: {beta1}")
print(f"Statistik t: {t_statistic}")
print(f"p-value: {p_value}")
# Out:
# Koefisien beta0: 25792.20019866869
# Koefisien beta1: 9449.962321455077
# Statistik t: 24.95009424096478
# p-value: 0.0

# %%
df1.shape[0]
# Out:
# 30
