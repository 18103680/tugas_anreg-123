# %%
import pandas as pd
import math

# %%
df1 = pd.read_csv('Salary_Data.csv')

df1
# Out:
#        x         y
# 0    1.1   39343.0
# 1    1.3   46205.0
# 2    1.5   37731.0
# 3    2.0   43525.0
# 4    2.2   39891.0
# 5    2.9   56642.0
# 6    3.0   60150.0
# 7    3.2   54445.0
# 8    3.2   64445.0
# 9    3.7   57189.0
# 10   3.9   63218.0
# 11   4.0   55794.0
# 12   4.0   56957.0
# 13   4.1   57081.0
# 14   4.5   61111.0
# 15   4.9   67938.0
# 16   5.1   66029.0
# 17   5.3   83088.0
# 18   5.9   81363.0
# 19   6.0   93940.0
# 20   6.8   91738.0
# 21   7.1   98273.0
# 22   7.9  101302.0
# 23   8.2  113812.0
# 24   8.7  109431.0
# 25   9.0  105582.0
# 26   9.5  116969.0
# 27   9.6  112635.0
# 28  10.3  122391.0
# 29  10.5  121872.0

# %%
print(df1['x'].describe())
# Out:
# count    30.000000
# mean      5.313333
# std       2.837888
# min       1.100000
# 25%       3.200000
# 50%       4.700000
# 75%       7.700000
# max      10.500000
# Name: x, dtype: float64

# %%
df1['xy'] = df1['x'] * df1['y']
df1['x^2'] = df1['x'] * df1['x']
df1['y^2'] = df1['y'] * df1['y']
df1
# Out:
#        x         y         xy     x^2           y^2
# 0    1.1   39343.0    43277.3    1.21  1.547872e+09
# 1    1.3   46205.0    60066.5    1.69  2.134902e+09
# 2    1.5   37731.0    56596.5    2.25  1.423628e+09
# 3    2.0   43525.0    87050.0    4.00  1.894426e+09
# 4    2.2   39891.0    87760.2    4.84  1.591292e+09
# 5    2.9   56642.0   164261.8    8.41  3.208316e+09
# 6    3.0   60150.0   180450.0    9.00  3.618022e+09
# 7    3.2   54445.0   174224.0   10.24  2.964258e+09
# 8    3.2   64445.0   206224.0   10.24  4.153158e+09
# 9    3.7   57189.0   211599.3   13.69  3.270582e+09
# 10   3.9   63218.0   246550.2   15.21  3.996516e+09
# 11   4.0   55794.0   223176.0   16.00  3.112970e+09
# 12   4.0   56957.0   227828.0   16.00  3.244100e+09
# 13   4.1   57081.0   234032.1   16.81  3.258241e+09
# 14   4.5   61111.0   274999.5   20.25  3.734554e+09
# 15   4.9   67938.0   332896.2   24.01  4.615572e+09
# 16   5.1   66029.0   336747.9   26.01  4.359829e+09
# 17   5.3   83088.0   440366.4   28.09  6.903616e+09
# 18   5.9   81363.0   480041.7   34.81  6.619938e+09
# 19   6.0   93940.0   563640.0   36.00  8.824724e+09
# 20   6.8   91738.0   623818.4   46.24  8.415861e+09
# 21   7.1   98273.0   697738.3   50.41  9.657583e+09
# 22   7.9  101302.0   800285.8   62.41  1.026210e+10
# 23   8.2  113812.0   933258.4   67.24  1.295317e+10
# 24   8.7  109431.0   952049.7   75.69  1.197514e+10
# 25   9.0  105582.0   950238.0   81.00  1.114756e+10
# 26   9.5  116969.0  1111205.5   90.25  1.368175e+10
# 27   9.6  112635.0  1081296.0   92.16  1.268664e+10
# 28  10.3  122391.0  1260627.3  106.09  1.497956e+10
# 29  10.5  121872.0  1279656.0  110.25  1.485278e+10

# %%
# menegtahui jumlah nya 
a= df1['x'].sum()
b= df1['y'].sum()
c =df1['xy'].sum()
d = df1['x^2'].sum()
e = df1['y^2'].sum()
f = df1['y'].mean()
g = df1['x'].mean()


print("Jumlah kolom 'x':", a)
print("Jumlah kolom 'y':", b)
print("Jumlah kolom 'xy':", c)
print("Jumlah kolom 'x^2':", d)
print("Jumlah kolom 'y^2':", e)
print('rata-rata y ', f)
print('rata-rata x ', g)
# Out:
# Jumlah kolom 'x': 159.4
# Jumlah kolom 'y': 2280090.0
# Jumlah kolom 'xy': 14321961.0
# Jumlah kolom 'x^2': 1080.5
# Jumlah kolom 'y^2': 195088658122.0
# rata-rata y  76003.0
# rata-rata x  5.3133333333333335

# %%
beta_1 = (c -((a*b)/30))/(d - (a**2/30))
beta_1
# Out:
# 9449.962321455081

# %%
beta_0 = f - beta_1*g
beta_0
# Out:
# 25792.200198668666

# %%
import numpy as np
import matplotlib.pyplot as plt
# Buat array x dari 0 sampai 30
x = df1['x']

# Hitung nilai y
y = beta_0 + beta_1 * x

# Plot
plt.figure(figsize=(12, 6))
plt.plot(x, y, label=f'y = {beta_0} + {beta_1} * x', color='blue')
plt.scatter(df1['x'], df1['y'], color='red', label='Data CSV')
plt.title('Plot dari y = beta_0 + beta_1 * x')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(0, 10,0.5)
plt.ylim(beta_0, beta_0 + beta_1 * 30)
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')
plt.xticks(np.arange(0, 10.5, 0.5)) 
plt.yticks(np.arange(0, 160000, 20000))
plt.grid()
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_11241/3543126352.py:16: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.xlim(0, 10,0.5)

# %%
y.head(20)
# Out:
# 0     36187.158752
# 1     38077.151217
# 2     39967.143681
# 3     44692.124842
# 4     46582.117306
# 5     53197.090931
# 6     54142.087163
# 7     56032.079627
# 8     56032.079627
# 9     60757.060788
# 10    62647.053252
# 11    63592.049484
# 12    63592.049484
# 13    64537.045717
# 14    68317.030645
# 15    72097.015574
# 16    73987.008038
# 17    75877.000502
# 18    81546.977895
# 19    82491.974127
# Name: x, dtype: float64

# %%
y.tail(10)
# Out:
# 20     90051.943985
# 21     92886.932681
# 22    100446.902538
# 23    103281.891235
# 24    108006.872395
# 25    110841.861092
# 26    115566.842252
# 27    116511.838485
# 28    123126.812110
# 29    125016.804574
# Name: x, dtype: float64

# %%
# menghitung R kuadrat
k =  ((y-f)**2)
l = ((df1['y']- f)**2)
JKR = k.sum()
JKS = l.sum()
R_kuadrat = JKR/JKS
R_kuadrat
# Out:
# 0.9569566641435093
